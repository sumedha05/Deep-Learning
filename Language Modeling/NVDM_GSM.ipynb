# %% [markdown]
# <a href="https://colab.research.google.com/github/soumilinandi/Deep-Learning/blob/main/Language%20Modeling/NVDM_GSM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/drive/MyDrive/NVDM-GSM-master
# Out:
# /content/drive/MyDrive/NVDM-GSM-master

# %%
# !python utils.py
# Out:
# 2021-04-22 13:37:09.546613: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0

# %%
pip install tensorflow==1.15
# Out:
# ...
#      |████████████████████████████████| 412.3MB 30kB/s
# ...
#      |████████████████████████████████| 512kB 23.9MB/s
# ...
#      |████████████████████████████████| 51kB 3.0MB/s
# ...
#      |████████████████████████████████| 3.8MB 30.5MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-cp37-none-any.whl size=7540 sha256=d356cd4313c2756de1dbc7833d5fe162ee5040737834392d3e9fce532732ccf8
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow-probability 0.12.1 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# ...
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: tensorflow-estimator 2.4.0
#     Uninstalling tensorflow-estimator-2.4.0:
#       Successfully uninstalled tensorflow-estimator-2.4.0
#   Found existing installation: tensorboard 2.4.1
# ...

# %%
# !python GSM.py
# Out:
# WARNING:tensorflow:From GSM.py:238: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From GSM.py:31: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0422 13:49:21.007758 140122135095168 module_wrapper.py:139] From GSM.py:31: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From GSM.py:35: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0422 13:49:21.011560 140122135095168 module_wrapper.py:139] From GSM.py:35: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/NVDM-GSM-master/utils.py:92: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# ...

# %% [markdown]
# https://github.com/linkstrife/NVDM-GSM/blob/master/GSM.py  https://github.com/YongfeiYan/Neural-Document-Modeling
